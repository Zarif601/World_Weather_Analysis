# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library
import time

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | samarai
# Processing Record 2 of Set 1 | los llanos de aridane
# Processing Record 3 of Set 1 | nishihara
# Processing Record 4 of Set 1 | morondava
# Processing Record 5 of Set 1 | oranjemund
# Processing Record 6 of Set 1 | horsham
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | ballina
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | janauba
# Processing Record 14 of Set 1 | saint george
# Processing Record 15 of Set 1 | plettenberg bay
# Processing Record 16 of Set 1 | mokshan
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | mount isa
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | bud
# Processing Record 25 of Set 1 | loikaw
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | stornoway
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | mora
# Processing Record 31 of Set 1 | ardakan
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | mushie
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | shebalino
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | manadhoo
# Processing Record 40 of Set 1 | pandan
# Processing Record 41 of Set 1 | camabatela
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | san patricio
# Processing Record 47 of Set 1 | taltal
# Processing Record 48 of Set 1 | snezhnogorsk
# Processing Record 49 of Set 1 | rahuri
# Processing Record 50 of Set 1 | san pedro
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | bandrele
# Processing Record 3 of Set 2 | shemgang
# Processing Record 4 of Set 2 | san carlos de bariloche
# Processing Record 5 of Set 2 | saskylakh
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | kamir
# Processing Record 8 of Set 2 | thunder bay
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | natal
# Processing Record 11 of Set 2 | dwarka
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | lompoc
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | vitim
# Processing Record 17 of Set 2 | sitka
# Processing Record 18 of Set 2 | cockburn town
# Processing Record 19 of Set 2 | whitehorse
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | molde
# Processing Record 22 of Set 2 | hofn
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | iquique
# Processing Record 26 of Set 2 | nikolskoye
# Processing Record 27 of Set 2 | itacoatiara
# Processing Record 28 of Set 2 | ryotsu
# Processing Record 29 of Set 2 | shagonar
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | lensk
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | metsavan
# Processing Record 34 of Set 2 | venado tuerto
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | mandera
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | okha
# Processing Record 39 of Set 2 | panzhihua
# Processing Record 40 of Set 2 | belyy yar
# Processing Record 41 of Set 2 | cherskiy
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | mount gambier
# Processing Record 44 of Set 2 | souillac
# Processing Record 45 of Set 2 | lewiston
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | codrington
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | birjand
# Processing Record 3 of Set 3 | ciras
# City not found. Skipping...
# Processing Record 4 of Set 3 | kodiak
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | tres lagoas
# Processing Record 7 of Set 3 | guerrero negro
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | walvis bay
# Processing Record 10 of Set 3 | magistralnyy
# Processing Record 11 of Set 3 | gulshat
# City not found. Skipping...
# Processing Record 12 of Set 3 | iralaya
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | anadyr
# Processing Record 15 of Set 3 | touros
# Processing Record 16 of Set 3 | rio gallegos
# Processing Record 17 of Set 3 | vanimo
# Processing Record 18 of Set 3 | astoria
# Processing Record 19 of Set 3 | pilar
# Processing Record 20 of Set 3 | kosh-agach
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | luderitz
# Processing Record 23 of Set 3 | nongan
# Processing Record 24 of Set 3 | celestun
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | chase
# Processing Record 28 of Set 3 | wad madani
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 3 | fort nelson
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | aripuana
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | aklavik
# Processing Record 36 of Set 3 | sao pedro do sul
# Processing Record 37 of Set 3 | ardalstangen
# Processing Record 38 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | orange cove
# Processing Record 41 of Set 3 | port hardy
# Processing Record 42 of Set 3 | mehamn
# Processing Record 43 of Set 3 | destin
# Processing Record 44 of Set 3 | tessalit
# Processing Record 45 of Set 3 | clyde river
# Processing Record 46 of Set 3 | santa fe
# Processing Record 47 of Set 3 | pitsunda
# Processing Record 48 of Set 3 | rafaela
# Processing Record 49 of Set 3 | kodinsk
# Processing Record 50 of Set 3 | ramnagar
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | vangaindrano
# Processing Record 3 of Set 4 | mansa
# Processing Record 4 of Set 4 | jiuquan
# Processing Record 5 of Set 4 | laurel
# Processing Record 6 of Set 4 | lorengau
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | jalu
# Processing Record 9 of Set 4 | westport
# Processing Record 10 of Set 4 | lata
# Processing Record 11 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 4 | bilibino
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | hilo
# Processing Record 16 of Set 4 | sakaiminato
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | sydney mines
# Processing Record 19 of Set 4 | severo-yeniseyskiy
# Processing Record 20 of Set 4 | guarapari
# Processing Record 21 of Set 4 | pochutla
# Processing Record 22 of Set 4 | lazaro cardenas
# Processing Record 23 of Set 4 | antalaha
# Processing Record 24 of Set 4 | zhigansk
# Processing Record 25 of Set 4 | sorong
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | nizhnevartovsk
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 4 | ambilobe
# Processing Record 31 of Set 4 | haines junction
# Processing Record 32 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 4 | san cristobal
# Processing Record 34 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 35 of Set 4 | pecos
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | grand baie
# Processing Record 39 of Set 4 | ironton
# Processing Record 40 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 4 | phalodi
# Processing Record 43 of Set 4 | bathsheba
# Processing Record 44 of Set 4 | qasigiannguit
# Processing Record 45 of Set 4 | khatanga
# Processing Record 46 of Set 4 | tabou
# Processing Record 47 of Set 4 | bathurst
# Processing Record 48 of Set 4 | tocopilla
# Processing Record 49 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 4 | ponta do sol
# Processing Record 1 of Set 5 | richards bay
# Processing Record 2 of Set 5 | grand forks
# Processing Record 3 of Set 5 | kavieng
# Processing Record 4 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | inhambane
# Processing Record 6 of Set 5 | kasongo-lunda
# Processing Record 7 of Set 5 | luanda
# Processing Record 8 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 5 | dire dawa
# Processing Record 10 of Set 5 | surt
# Processing Record 11 of Set 5 | marsa matruh
# Processing Record 12 of Set 5 | lebu
# Processing Record 13 of Set 5 | pareora
# Processing Record 14 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 15 of Set 5 | severo-kurilsk
# Processing Record 16 of Set 5 | sinnamary
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | villamontes
# Processing Record 19 of Set 5 | nelson bay
# Processing Record 20 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | saint-pierre
# Processing Record 22 of Set 5 | kalmunai
# Processing Record 23 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 5 | tiksi
# Processing Record 25 of Set 5 | tuburan
# Processing Record 26 of Set 5 | samarinda
# Processing Record 27 of Set 5 | juba
# Processing Record 28 of Set 5 | kampong thum
# Processing Record 29 of Set 5 | north las vegas
# Processing Record 30 of Set 5 | prince rupert
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | qui nhon
# Processing Record 33 of Set 5 | hami
# Processing Record 34 of Set 5 | chepareria
# Processing Record 35 of Set 5 | batalha
# Processing Record 36 of Set 5 | tura
# Processing Record 37 of Set 5 | shibarghan
# City not found. Skipping...
# Processing Record 38 of Set 5 | cabinda
# Processing Record 39 of Set 5 | panjakent
# Processing Record 40 of Set 5 | czersk
# Processing Record 41 of Set 5 | bonthe
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | coahuayana
# Processing Record 44 of Set 5 | isakly
# Processing Record 45 of Set 5 | geraldton
# Processing Record 46 of Set 5 | namibe
# Processing Record 47 of Set 5 | carutapera
# Processing Record 48 of Set 5 | vardo
# Processing Record 49 of Set 5 | beaverlodge
# Processing Record 50 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 6 | villiers
# Processing Record 3 of Set 6 | pangnirtung
# Processing Record 4 of Set 6 | puro
# Processing Record 5 of Set 6 | meiningen
# Processing Record 6 of Set 6 | dongzhen
# Processing Record 7 of Set 6 | roald
# Processing Record 8 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 9 of Set 6 | berlevag
# Processing Record 10 of Set 6 | port macquarie
# Processing Record 11 of Set 6 | kaeo
# Processing Record 12 of Set 6 | san isidro
# Processing Record 13 of Set 6 | coos bay
# Processing Record 14 of Set 6 | egvekinot
# Processing Record 15 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | marawi
# Processing Record 18 of Set 6 | lagoa
# Processing Record 19 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 6 | coruripe
# Processing Record 21 of Set 6 | joshimath
# Processing Record 22 of Set 6 | nantucket
# Processing Record 23 of Set 6 | pisco
# Processing Record 24 of Set 6 | namtsy
# Processing Record 25 of Set 6 | flin flon
# Processing Record 26 of Set 6 | rocha
# Processing Record 27 of Set 6 | liberal
# Processing Record 28 of Set 6 | bani
# Processing Record 29 of Set 6 | huarmey
# Processing Record 30 of Set 6 | avera
# Processing Record 31 of Set 6 | altay
# Processing Record 32 of Set 6 | boyolangu
# Processing Record 33 of Set 6 | murgab
# Processing Record 34 of Set 6 | uberaba
# Processing Record 35 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 6 | eunice
# Processing Record 37 of Set 6 | jablah
# Processing Record 38 of Set 6 | marzuq
# Processing Record 39 of Set 6 | provideniya
# Processing Record 40 of Set 6 | doka
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | wajima
# Processing Record 43 of Set 6 | esperance
# Processing Record 44 of Set 6 | mayo
# Processing Record 45 of Set 6 | mpika
# Processing Record 46 of Set 6 | karimpur
# Processing Record 47 of Set 6 | dunedin
# Processing Record 48 of Set 6 | dudinka
# Processing Record 49 of Set 6 | deputatskiy
# Processing Record 50 of Set 6 | san quintin
# Processing Record 1 of Set 7 | manado
# Processing Record 2 of Set 7 | umm lajj
# Processing Record 3 of Set 7 | ugoofaaru
# Processing Record 4 of Set 7 | havre-saint-pierre
# Processing Record 5 of Set 7 | hualmay
# Processing Record 6 of Set 7 | perth
# Processing Record 7 of Set 7 | hithadhoo
# Processing Record 8 of Set 7 | manolas
# Processing Record 9 of Set 7 | ancud
# Processing Record 10 of Set 7 | pogranichnyy
# Processing Record 11 of Set 7 | forestville
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | libreville
# Processing Record 14 of Set 7 | tigzirt
# Processing Record 15 of Set 7 | dalvik
# Processing Record 16 of Set 7 | monrovia
# Processing Record 17 of Set 7 | molnlycke
# Processing Record 18 of Set 7 | houma
# Processing Record 19 of Set 7 | salalah
# Processing Record 20 of Set 7 | nouadhibou
# Processing Record 21 of Set 7 | moose factory
# Processing Record 22 of Set 7 | umm kaddadah
# Processing Record 23 of Set 7 | muromtsevo
# Processing Record 24 of Set 7 | beringovskiy
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | xinxiang
# Processing Record 27 of Set 7 | ondjiva
# Processing Record 28 of Set 7 | scarborough
# Processing Record 29 of Set 7 | cartagena del chaira
# Processing Record 30 of Set 7 | buala
# Processing Record 31 of Set 7 | mount pleasant
# Processing Record 32 of Set 7 | nayoro
# Processing Record 33 of Set 7 | fairbanks
# Processing Record 34 of Set 7 | uvira
# Processing Record 35 of Set 7 | necochea
# Processing Record 36 of Set 7 | araouane
# Processing Record 37 of Set 7 | hirara
# Processing Record 38 of Set 7 | soyo
# Processing Record 39 of Set 7 | meulaboh
# Processing Record 40 of Set 7 | lumeje
# Processing Record 41 of Set 7 | nizwa
# Processing Record 42 of Set 7 | asau
# Processing Record 43 of Set 7 | mandali
# Processing Record 44 of Set 7 | ahipara
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | vila franca do campo
# Processing Record 47 of Set 7 | texarkana
# Processing Record 48 of Set 7 | bilma
# Processing Record 49 of Set 7 | verkhnyaya sysert
# Processing Record 50 of Set 7 | kaduqli
# Processing Record 1 of Set 8 | leningradskiy
# Processing Record 2 of Set 8 | yerbogachen
# Processing Record 3 of Set 8 | kysyl-syr
# Processing Record 4 of Set 8 | vilhena
# Processing Record 5 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 6 of Set 8 | byron bay
# Processing Record 7 of Set 8 | sawtell
# Processing Record 8 of Set 8 | belz
# Processing Record 9 of Set 8 | coquimbo
# Processing Record 10 of Set 8 | ilhabela
# Processing Record 11 of Set 8 | rundu
# Processing Record 12 of Set 8 | zyryanka
# Processing Record 13 of Set 8 | ayagoz
# Processing Record 14 of Set 8 | tevaitoa
# Processing Record 15 of Set 8 | dali
# Processing Record 16 of Set 8 | davila
# Processing Record 17 of Set 8 | xuddur
# Processing Record 18 of Set 8 | sao joao da barra
# Processing Record 19 of Set 8 | iskateley
# Processing Record 20 of Set 8 | tuatapere
# Processing Record 21 of Set 8 | great falls
# Processing Record 22 of Set 8 | boa vista
# Processing Record 23 of Set 8 | eyl
# Processing Record 24 of Set 8 | hof
# Processing Record 25 of Set 8 | belmonte
# Processing Record 26 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 8 | det udom
# Processing Record 28 of Set 8 | cascais
# Processing Record 29 of Set 8 | mbalmayo
# Processing Record 30 of Set 8 | tiznit
# Processing Record 31 of Set 8 | boulogne-sur-mer
# Processing Record 32 of Set 8 | alofi
# Processing Record 33 of Set 8 | luocheng
# Processing Record 34 of Set 8 | borgo san dalmazzo
# Processing Record 35 of Set 8 | manaure
# Processing Record 36 of Set 8 | mandalgovi
# Processing Record 37 of Set 8 | raudeberg
# Processing Record 38 of Set 8 | portland
# Processing Record 39 of Set 8 | beyneu
# Processing Record 40 of Set 8 | the pas
# Processing Record 41 of Set 8 | port-gentil
# Processing Record 42 of Set 8 | isangel
# Processing Record 43 of Set 8 | la crosse
# Processing Record 44 of Set 8 | namatanai
# Processing Record 45 of Set 8 | nabire
# Processing Record 46 of Set 8 | mpulungu
# Processing Record 47 of Set 8 | komsomolskiy
# Processing Record 48 of Set 8 | igrim
# Processing Record 49 of Set 8 | belmopan
# Processing Record 50 of Set 8 | xai-xai
# Processing Record 1 of Set 9 | dongying
# Processing Record 2 of Set 9 | ilobu
# Processing Record 3 of Set 9 | lavrentiya
# Processing Record 4 of Set 9 | yanaul
# Processing Record 5 of Set 9 | goderich
# Processing Record 6 of Set 9 | yar-sale
# Processing Record 7 of Set 9 | sakakah
# Processing Record 8 of Set 9 | dakar
# Processing Record 9 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 9 | teya
# Processing Record 11 of Set 9 | taormina
# Processing Record 12 of Set 9 | anamur
# Processing Record 13 of Set 9 | jishou
# Processing Record 14 of Set 9 | taoudenni
# Processing Record 15 of Set 9 | gidam
# Processing Record 16 of Set 9 | kamenka
# Processing Record 17 of Set 9 | ketchikan
# Processing Record 18 of Set 9 | sanandaj
# Processing Record 19 of Set 9 | hammel
# Processing Record 20 of Set 9 | miechow
# Processing Record 21 of Set 9 | mahebourg
# Processing Record 22 of Set 9 | mabai
# Processing Record 23 of Set 9 | buin
# Processing Record 24 of Set 9 | capreol
# Processing Record 25 of Set 9 | saint-louis
# Processing Record 26 of Set 9 | east wenatchee bench
# Processing Record 27 of Set 9 | zambezi
# Processing Record 28 of Set 9 | husavik
# Processing Record 29 of Set 9 | vila velha
# Processing Record 30 of Set 9 | nurota
# Processing Record 31 of Set 9 | talnakh
# Processing Record 32 of Set 9 | klyuchi
# Processing Record 33 of Set 9 | anan
# Processing Record 34 of Set 9 | praia
# Processing Record 35 of Set 9 | jambi
# Processing Record 36 of Set 9 | bengkulu
# Processing Record 37 of Set 9 | lasa
# Processing Record 38 of Set 9 | daru
# Processing Record 39 of Set 9 | inuvik
# Processing Record 40 of Set 9 | ola
# Processing Record 41 of Set 9 | buckeye
# Processing Record 42 of Set 9 | nuuk
# Processing Record 43 of Set 9 | lucapa
# Processing Record 44 of Set 9 | clonakilty
# Processing Record 45 of Set 9 | ourossogui
# Processing Record 46 of Set 9 | ulaanbaatar
# Processing Record 47 of Set 9 | saqqez
# Processing Record 48 of Set 9 | ende
# Processing Record 49 of Set 9 | honiara
# Processing Record 50 of Set 9 | krasnovishersk
# Processing Record 1 of Set 10 | natchez
# Processing Record 2 of Set 10 | mwense
# Processing Record 3 of Set 10 | puerto el triunfo
# Processing Record 4 of Set 10 | vysokogornyy
# Processing Record 5 of Set 10 | jardim
# Processing Record 6 of Set 10 | bongaree
# Processing Record 7 of Set 10 | opuwo
# Processing Record 8 of Set 10 | valdivia
# Processing Record 9 of Set 10 | tilichiki
# Processing Record 10 of Set 10 | skjervoy
# Processing Record 11 of Set 10 | astana
# Processing Record 12 of Set 10 | simdega
# Processing Record 13 of Set 10 | aginskoye
# Processing Record 14 of Set 10 | domoni
# Processing Record 15 of Set 10 | muros
# Processing Record 16 of Set 10 | kalmar
# Processing Record 17 of Set 10 | hurghada
# Processing Record 18 of Set 10 | bandarbeyla
# Processing Record 19 of Set 10 | owando
# Processing Record 20 of Set 10 | santiago
# Processing Record 21 of Set 10 | saint-augustin
# Processing Record 22 of Set 10 | medea
# Processing Record 23 of Set 10 | moses lake
# Processing Record 24 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 25 of Set 10 | stepnyak
# Processing Record 26 of Set 10 | kushiro
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | digha
# Processing Record 30 of Set 10 | rawson
# Processing Record 31 of Set 10 | oparino
# Processing Record 32 of Set 10 | pacific grove
# Processing Record 33 of Set 10 | saint anthony
# Processing Record 34 of Set 10 | mbuji-mayi
# Processing Record 35 of Set 10 | comodoro rivadavia
# Processing Record 36 of Set 10 | maragogi
# Processing Record 37 of Set 10 | dobryanka
# Processing Record 38 of Set 10 | elmvale
# Processing Record 39 of Set 10 | oxbow
# Processing Record 40 of Set 10 | mastic beach
# Processing Record 41 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 42 of Set 10 | saldanha
# Processing Record 43 of Set 10 | lupiro
# Processing Record 44 of Set 10 | dasoguz
# Processing Record 45 of Set 10 | olafsvik
# Processing Record 46 of Set 10 | camacha
# Processing Record 47 of Set 10 | am timan
# Processing Record 48 of Set 10 | hambantota
# Processing Record 49 of Set 10 | gamba
# Processing Record 50 of Set 10 | erzincan
# Processing Record 1 of Set 11 | itarema
# Processing Record 2 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 11 | goba
# Processing Record 4 of Set 11 | buraydah
# Processing Record 5 of Set 11 | esso
# Processing Record 6 of Set 11 | perez
# Processing Record 7 of Set 11 | omsukchan
# Processing Record 8 of Set 11 | dingzhou
# Processing Record 9 of Set 11 | blagoyevo
# Processing Record 10 of Set 11 | yetkul
# Processing Record 11 of Set 11 | dongfeng
# Processing Record 12 of Set 11 | likasi
# Processing Record 13 of Set 11 | beloha
# Processing Record 14 of Set 11 | biak
# Processing Record 15 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 16 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 11 | korhogo
# Processing Record 18 of Set 11 | ambon
# Processing Record 19 of Set 11 | dinar
# Processing Record 20 of Set 11 | tucuman
# Processing Record 21 of Set 11 | todos santos
# Processing Record 22 of Set 11 | redmond
# Processing Record 23 of Set 11 | chifeng
# Processing Record 24 of Set 11 | kamaishi
# Processing Record 25 of Set 11 | kulunda
# Processing Record 26 of Set 11 | hellin
# Processing Record 27 of Set 11 | lebedinyy
# Processing Record 28 of Set 11 | pavilosta
# Processing Record 29 of Set 11 | naryan-mar
# Processing Record 30 of Set 11 | la ronge
# Processing Record 31 of Set 11 | primorsko-akhtarsk
# Processing Record 32 of Set 11 | gaogou
# Processing Record 33 of Set 11 | baykit
# Processing Record 34 of Set 11 | razole
# Processing Record 35 of Set 11 | kudahuvadhoo
# Processing Record 36 of Set 11 | bonavista
# Processing Record 37 of Set 11 | linxia
# Processing Record 38 of Set 11 | khash
# Processing Record 39 of Set 11 | muroto
# Processing Record 40 of Set 11 | vao
# Processing Record 41 of Set 11 | susuman
# Processing Record 42 of Set 11 | katsuura
# Processing Record 43 of Set 11 | bubaque
# Processing Record 44 of Set 11 | cururupu
# Processing Record 45 of Set 11 | semnan
# Processing Record 46 of Set 11 | oskarshamn
# Processing Record 47 of Set 11 | ilulissat
# Processing Record 48 of Set 11 | maoming
# Processing Record 49 of Set 11 | keti bandar
# Processing Record 50 of Set 11 | kutum
# Processing Record 1 of Set 12 | katangli
# Processing Record 2 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 12 | yalvac
# Processing Record 4 of Set 12 | kidal
# Processing Record 5 of Set 12 | naugarzan
# City not found. Skipping...
# Processing Record 6 of Set 12 | izvestkovyy
# Processing Record 7 of Set 12 | juegang
# Processing Record 8 of Set 12 | reshetnikovo
# Processing Record 9 of Set 12 | dutlwe
# Processing Record 10 of Set 12 | chinhoyi
# Processing Record 11 of Set 12 | abatskoye
# Processing Record 12 of Set 12 | leshukonskoye
# Processing Record 13 of Set 12 | nanortalik
# Processing Record 14 of Set 12 | zaysan
# Processing Record 15 of Set 12 | gambela
# Processing Record 16 of Set 12 | durres
# Processing Record 17 of Set 12 | boca do acre
# Processing Record 18 of Set 12 | makakilo city
# Processing Record 19 of Set 12 | chumikan
# Processing Record 20 of Set 12 | quickborn
# Processing Record 21 of Set 12 | heyang
# Processing Record 22 of Set 12 | paamiut
# Processing Record 23 of Set 12 | alvin
# Processing Record 24 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 12 | cayenne
# Processing Record 26 of Set 12 | obregon
# Processing Record 27 of Set 12 | manggar
# Processing Record 28 of Set 12 | diffa
# Processing Record 29 of Set 12 | el dorado
# Processing Record 30 of Set 12 | udachnyy
# Processing Record 31 of Set 12 | khani
# Processing Record 32 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 12 | ocotal
# Processing Record 34 of Set 12 | matane
# Processing Record 35 of Set 12 | kruisfontein
# Processing Record 36 of Set 12 | salinas
# Processing Record 37 of Set 12 | nenjiang
# Processing Record 38 of Set 12 | kieta
# Processing Record 39 of Set 12 | chekhov
# Processing Record 40 of Set 12 | del rio
# Processing Record 41 of Set 12 | correntina
# Processing Record 42 of Set 12 | price
# Processing Record 43 of Set 12 | parati
# Processing Record 44 of Set 12 | grindavik
# Processing Record 45 of Set 12 | ierapetra
# Processing Record 46 of Set 12 | srisailam
# Processing Record 47 of Set 12 | kendari
# Processing Record 48 of Set 12 | estelle
# Processing Record 49 of Set 12 | rebokon
# City not found. Skipping...
# Processing Record 50 of Set 12 | half moon bay
# Processing Record 1 of Set 13 | yeppoon
# Processing Record 2 of Set 13 | colares
# Processing Record 3 of Set 13 | zalantun
# Processing Record 4 of Set 13 | punta
# Processing Record 5 of Set 13 | avila
# Processing Record 6 of Set 13 | fort saint james
# Processing Record 7 of Set 13 | tasca
# Processing Record 8 of Set 13 | acapulco
# Processing Record 9 of Set 13 | nieuw amsterdam
# Processing Record 10 of Set 13 | hisai
# Processing Record 11 of Set 13 | tual
# Processing Record 12 of Set 13 | bam
# Processing Record 13 of Set 13 | cabatuan
# Processing Record 14 of Set 13 | huoqiu
# Processing Record 15 of Set 13 | kathmandu
# Processing Record 16 of Set 13 | torit
# Processing Record 17 of Set 13 | paragominas
# Processing Record 18 of Set 13 | margate
# Processing Record 19 of Set 13 | rantepao
# Processing Record 20 of Set 13 | old road
# City not found. Skipping...
# Processing Record 21 of Set 13 | maniitsoq
# Processing Record 22 of Set 13 | emerald
# Processing Record 23 of Set 13 | bhusawal
# Processing Record 24 of Set 13 | galbshtadt
# Processing Record 25 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 13 | quatre cocos
# Processing Record 27 of Set 13 | wattegama
# Processing Record 28 of Set 13 | broken hill
# Processing Record 29 of Set 13 | pangai
# Processing Record 30 of Set 13 | caceres
# Processing Record 31 of Set 13 | norman wells
# Processing Record 32 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 13 | luau
# Processing Record 34 of Set 13 | san lorenzo
# Processing Record 35 of Set 13 | mata
# Processing Record 36 of Set 13 | miyako
# Processing Record 37 of Set 13 | ust-nera
# Processing Record 38 of Set 13 | conversion
# Processing Record 39 of Set 13 | sumbe
# Processing Record 40 of Set 13 | villarrica
# Processing Record 41 of Set 13 | jawhar
# Processing Record 42 of Set 13 | vila do maio
# Processing Record 43 of Set 13 | brownsville
# Processing Record 44 of Set 13 | maimon
# City not found. Skipping...
# Processing Record 45 of Set 13 | laguna
# Processing Record 46 of Set 13 | ho
# City not found. Skipping...
# Processing Record 47 of Set 13 | ekibastuz
# Processing Record 48 of Set 13 | the valley
# Processing Record 49 of Set 13 | bolivar
# Processing Record 50 of Set 13 | evensk
# Processing Record 1 of Set 14 | narsaq
# Processing Record 2 of Set 14 | cuiaba
# Processing Record 3 of Set 14 | paramonga
# Processing Record 4 of Set 14 | bria
# Processing Record 5 of Set 14 | stephenville
# Processing Record 6 of Set 14 | lhokseumawe
# Processing Record 7 of Set 14 | khanewal
# Processing Record 8 of Set 14 | puerto wilches
# Processing Record 9 of Set 14 | takoradi
# Processing Record 10 of Set 14 | yala
# Processing Record 11 of Set 14 | japura
# Processing Record 12 of Set 14 | myitkyina
# Processing Record 13 of Set 14 | havoysund
# Processing Record 14 of Set 14 | canovanas
# Processing Record 15 of Set 14 | dvinskoy
# Processing Record 16 of Set 14 | disraeli
# Processing Record 17 of Set 14 | tomatlan
# Processing Record 18 of Set 14 | azuaga
# Processing Record 19 of Set 14 | katherine
# Processing Record 20 of Set 14 | robe
# Processing Record 21 of Set 14 | kuching
# Processing Record 22 of Set 14 | traverse city
# Processing Record 23 of Set 14 | kirksville
# Processing Record 24 of Set 14 | balintore
# Processing Record 25 of Set 14 | concepcion del oro
# Processing Record 26 of Set 14 | zlitan
# Processing Record 27 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 14 | puerto escondido
# Processing Record 29 of Set 14 | port-cartier
# Processing Record 30 of Set 14 | rincon
# Processing Record 31 of Set 14 | baturaja
# Processing Record 32 of Set 14 | ghanzi
# Processing Record 33 of Set 14 | yulara
# Processing Record 34 of Set 14 | macklin
# Processing Record 35 of Set 14 | langenburg
# Processing Record 36 of Set 14 | shelburne
# Processing Record 37 of Set 14 | pangody
# Processing Record 38 of Set 14 | yanam
# Processing Record 39 of Set 14 | malibu
# Processing Record 40 of Set 14 | impfondo
# Processing Record 41 of Set 14 | gaoual
# Processing Record 42 of Set 14 | mecca
# Processing Record 43 of Set 14 | champerico
# Processing Record 44 of Set 14 | jati
# Processing Record 45 of Set 14 | irbil
# Processing Record 46 of Set 14 | alta floresta
# Processing Record 47 of Set 14 | clonmel
# Processing Record 48 of Set 14 | uige
# Processing Record 49 of Set 14 | puerto madryn
# Processing Record 50 of Set 14 | le port
# Processing Record 1 of Set 15 | seoul
# Processing Record 2 of Set 15 | korla
# Processing Record 3 of Set 15 | ndjole
# Processing Record 4 of Set 15 | oussouye
# Processing Record 5 of Set 15 | mayakonda
# Processing Record 6 of Set 15 | sayyan
# Processing Record 7 of Set 15 | marinette
# Processing Record 8 of Set 15 | aksarka
# Processing Record 9 of Set 15 | auki
# Processing Record 10 of Set 15 | gurgentepe
# Processing Record 11 of Set 15 | galesong
# Processing Record 12 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 13 of Set 15 | middelburg
# Processing Record 14 of Set 15 | alenquer
# Processing Record 15 of Set 15 | kuusamo
# Processing Record 16 of Set 15 | ntcheu
# Processing Record 17 of Set 15 | sabancuy
# Processing Record 18 of Set 15 | vanavara
# Processing Record 19 of Set 15 | tateyama
# Processing Record 20 of Set 15 | adilcevaz
# Processing Record 21 of Set 15 | solnechnyy
# Processing Record 22 of Set 15 | pahrump
# Processing Record 23 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 15 | asuncion
# Processing Record 25 of Set 15 | businga
# Processing Record 26 of Set 15 | robertsport
# Processing Record 27 of Set 15 | tenenkou
# Processing Record 28 of Set 15 | santo domingo
# Processing Record 29 of Set 15 | karratha
# Processing Record 30 of Set 15 | dzaoudzi
# Processing Record 31 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 15 | grand gaube
# Processing Record 33 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 15 | neiafu
# Processing Record 35 of Set 15 | venice
# Processing Record 36 of Set 15 | kloulklubed
# Processing Record 37 of Set 15 | great yarmouth
# Processing Record 38 of Set 15 | burgas
# Processing Record 39 of Set 15 | yaan
# Processing Record 40 of Set 15 | kandrian
# Processing Record 41 of Set 15 | jamame
# Processing Record 42 of Set 15 | baft
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Counting the total number of records retrieved
len(city_data)
# Out:
# 689

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Samarai -10.6167  150.6667     86.76        67         100
# 1  Los Llanos De Aridane  28.6585  -17.9182     56.95        77          20
# 2              Nishihara  26.1842  127.7558     76.68        97         100
# 3              Morondava -20.2833   44.2833     77.67        90           8
# 4             Oranjemund -28.5500   16.4333     56.39        95           1
# 5                Horsham  51.0640   -0.3272     47.53        75           0
# 6            Tuktoyaktuk  69.4541 -133.0374     -7.60        71           0
# 7                 Barrow  71.2906 -156.7887      1.42        78         100
# 8                  Airai  -8.9266  125.4092     70.86        67          80
# 9               Hamilton  39.1834  -84.5333     44.98        82         100
#
#    Wind Speed Country Current Description
# 0       14.14      PG     overcast clouds
# 1        6.91      ES          few clouds
# 2       24.16      JP                mist
# 3        5.59      MG           clear sky
# 4        2.66      NA           clear sky
# 5        4.61      GB           clear sky
# 6       17.27      CA           clear sky
# 7       24.16      US     overcast clouds
# 8        1.81      TL       broken clouds
# 9        9.22      US          light rain

# %%
# Reordering the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Samarai      PG -10.6167  150.6667     86.76        67
# 1  Los Llanos De Aridane      ES  28.6585  -17.9182     56.95        77
# 2              Nishihara      JP  26.1842  127.7558     76.68        97
# 3              Morondava      MG -20.2833   44.2833     77.67        90
# 4             Oranjemund      NA -28.5500   16.4333     56.39        95
# 5                Horsham      GB  51.0640   -0.3272     47.53        75
# 6            Tuktoyaktuk      CA  69.4541 -133.0374     -7.60        71
# 7                 Barrow      US  71.2906 -156.7887      1.42        78
# 8                  Airai      TL  -8.9266  125.4092     70.86        67
# 9               Hamilton      US  39.1834  -84.5333     44.98        82
#
#    Cloudiness  Wind Speed Current Description
# 0         100       14.14     overcast clouds
# 1          20        6.91          few clouds
# 2         100       24.16                mist
# 3           8        5.59           clear sky
# 4           1        2.66           clear sky
# 5           0        4.61           clear sky
# 6           0       17.27           clear sky
# 7         100       24.16     overcast clouds
# 8          80        1.81       broken clouds
# 9         100        9.22          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
